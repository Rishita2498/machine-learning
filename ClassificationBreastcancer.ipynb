# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents'

# %%
os.chdir('C:/Users/dell/Desktop/datas')

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('data.csv')

# %%
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
from sklearn import preprocessing

# %%
data=data.drop(['id'],axis=1)

# %%
data
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M       17.990         10.38          122.80     1001.0
# 1           M       20.570         17.77          132.90     1326.0
# 2           M       19.690         21.25          130.00     1203.0
# 3           M       11.420         20.38           77.58      386.1
# 4           M       20.290         14.34          135.10     1297.0
# 5           M       12.450         15.70           82.57      477.1
# 6           M       18.250         19.98          119.60     1040.0
# 7           M       13.710         20.83           90.20      577.9
# 8           M       13.000         21.82           87.50      519.8
# 9           M       12.460         24.04           83.97      475.9
# 10          M       16.020         23.24          102.70      797.8
# 11          M       15.780         17.89          103.60      781.0
# 12          M       19.170         24.80          132.40     1123.0
# ...

# %%
data.diagnosis.value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data['diagnosis'].replace(['M','B'],['Malignant','Benign'],inplace=True)

# %%
data
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    Malignant       17.990         10.38          122.80     1001.0
# 1    Malignant       20.570         17.77          132.90     1326.0
# 2    Malignant       19.690         21.25          130.00     1203.0
# 3    Malignant       11.420         20.38           77.58      386.1
# 4    Malignant       20.290         14.34          135.10     1297.0
# 5    Malignant       12.450         15.70           82.57      477.1
# 6    Malignant       18.250         19.98          119.60     1040.0
# 7    Malignant       13.710         20.83           90.20      577.9
# 8    Malignant       13.000         21.82           87.50      519.8
# 9    Malignant       12.460         24.04           83.97      475.9
# 10   Malignant       16.020         23.24          102.70      797.8
# 11   Malignant       15.780         17.89          103.60      781.0
# 12   Malignant       19.170         24.80          132.40     1123.0
# ...

# %%
a=data.loc[:,['radius_mean','area_mean','smoothness_mean']] 
#slicing to get particular columns from the data

# %%
a
# Out:
#      radius_mean  area_mean  smoothness_mean
# 0         17.990     1001.0          0.11840
# 1         20.570     1326.0          0.08474
# 2         19.690     1203.0          0.10960
# 3         11.420      386.1          0.14250
# 4         20.290     1297.0          0.10030
# 5         12.450      477.1          0.12780
# 6         18.250     1040.0          0.09463
# 7         13.710      577.9          0.11890
# 8         13.000      519.8          0.12730
# 9         12.460      475.9          0.11860
# 10        16.020      797.8          0.08206
# 11        15.780      781.0          0.09710
# 12        19.170     1123.0          0.09740
# 13        15.850      782.7          0.08401
# 14        13.730      578.3          0.11310
# 15        14.540      658.8          0.11390
# 16        14.680      684.5          0.09867
# 17        16.130      798.8          0.11700
# 18        19.810     1260.0          0.09831
# 19        13.540      566.3          0.09779
# ...

# %%
a.describe()
# Out:
#        radius_mean    area_mean  smoothness_mean
# count   569.000000   569.000000       569.000000
# mean     14.127292   654.889104         0.096360
# std       3.524049   351.914129         0.014064
# min       6.981000   143.500000         0.052630
# 25%      11.700000   420.300000         0.086370
# 50%      13.370000   551.100000         0.095870
# 75%      15.780000   782.700000         0.105300
# max      28.110000  2501.000000         0.163400

# %%
# to remove randomness and make data consistent normalization is necessary
x=data.iloc[:,1:31]
y=data.iloc[:,0]

# %%
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         17.990         10.38          122.80     1001.0          0.11840
# 1         20.570         17.77          132.90     1326.0          0.08474
# 2         19.690         21.25          130.00     1203.0          0.10960
# 3         11.420         20.38           77.58      386.1          0.14250
# 4         20.290         14.34          135.10     1297.0          0.10030
# 5         12.450         15.70           82.57      477.1          0.12780
# 6         18.250         19.98          119.60     1040.0          0.09463
# 7         13.710         20.83           90.20      577.9          0.11890
# 8         13.000         21.82           87.50      519.8          0.12730
# 9         12.460         24.04           83.97      475.9          0.11860
# 10        16.020         23.24          102.70      797.8          0.08206
# ...

# %%
y
# Out:
# 0      Malignant
# 1      Malignant
# 2      Malignant
# 3      Malignant
# 4      Malignant
# 5      Malignant
# 6      Malignant
# 7      Malignant
# 8      Malignant
# 9      Malignant
# 10     Malignant
# 11     Malignant
# 12     Malignant
# 13     Malignant
# 14     Malignant
# 15     Malignant
# 16     Malignant
# 17     Malignant
# 18     Malignant
# 19        Benign
# 20        Benign
# 21        Benign
# 22     Malignant
# 23     Malignant
# 24     Malignant
# 25     Malignant
# 26     Malignant
# 27     Malignant
# 28     Malignant
# 29     Malignant
#          ...
# 539       Benign
# 540       Benign
# 541       Benign
# 542       Benign
# 543       Benign
# 544       Benign
# 545       Benign
# 546       Benign
# 547       Benign
# 548       Benign
# 549       Benign
# 550       Benign
# 551       Benign
# 552       Benign
# 553       Benign
# 554       Benign
# 555       Benign
# 556       Benign
# 557       Benign
# 558       Benign
# 559       Benign
# ...

# %%
#min-max scaler technique to fit data between 0 and 1
#x-min(x)/max(x)-min(x) ratio  all the values are changed to 0 and 1 user defined function
# virtual data to be analysed
minmax=preprocessing.MinMaxScaler(feature_range=(0,1))
minmax.fit(x).transform(x)
# Out:
# array([[ 0.52103744,  0.0226581 ,  0.54598853, ...,  0.91202749,
#          0.59846245,  0.41886396],
#        [ 0.64314449,  0.27257355,  0.61578329, ...,  0.63917526,
#          0.23358959,  0.22287813],
#        [ 0.60149557,  0.3902604 ,  0.59574321, ...,  0.83505155,
#          0.40370589,  0.21343303],
#        ...,
#        [ 0.45525108,  0.62123774,  0.44578813, ...,  0.48728522,
#          0.12872068,  0.1519087 ],
#        [ 0.64456434,  0.66351031,  0.66553797, ...,  0.91065292,
#          0.49714173,  0.45231536],
#        [ 0.03686876,  0.50152181,  0.02853984, ...,  0.        ,
#          0.25744136,  0.10068215]])

# %%
x['area_mean'].describe()
# Out:
# count     569.000000
# mean      654.889104
# std       351.914129
# min       143.500000
# 25%       420.300000
# 50%       551.100000
# 75%       782.700000
# max      2501.000000
# Name: area_mean, dtype: float64

# %%
from sklearn import cross_validation,neighbors
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 559       11.510         23.93           74.52      403.5          0.09261
# 380       11.270         12.96           73.16      386.3          0.12370
# 30        18.630         25.11          124.80     1088.0          0.10640
# 208       13.110         22.54           87.02      529.4          0.10020
# 43        13.280         20.28           87.32      545.2          0.10410
# 424        9.742         19.12           61.93      289.7          0.10750
# 88        12.360         21.80           79.78      466.1          0.08772
# 502       12.540         16.32           81.25      476.3          0.11580
# 473       12.270         29.97           77.42      465.4          0.07699
# 327       12.030         17.93           76.09      446.0          0.07683
# 226       10.440         15.46           66.62      329.6          0.10530
# ...

# %%
y_train
# Out:
# 559       Benign
# 380       Benign
# 30     Malignant
# 208       Benign
# 43     Malignant
# 424       Benign
# 88        Benign
# 502       Benign
# 473       Benign
# 327       Benign
# 226       Benign
# 132    Malignant
# 75     Malignant
# 292       Benign
# 406       Benign
# 213    Malignant
# 176       Benign
# 86     Malignant
# 470       Benign
# 312       Benign
# 534       Benign
# 173       Benign
# 563    Malignant
# 314       Benign
# 54     Malignant
# 558       Benign
# 351    Malignant
# 417    Malignant
# 142       Benign
# 5      Malignant
#          ...
# 29     Malignant
# 194    Malignant
# 459       Benign
# 21        Benign
# 56     Malignant
# 460    Malignant
# 42     Malignant
# 12     Malignant
# 211       Benign
# 115       Benign
# 449    Malignant
# 520       Benign
# 375       Benign
# 61        Benign
# 360       Benign
# 227       Benign
# 10     Malignant
# 38     Malignant
# 510       Benign
# 272    Malignant
# 95     Malignant
# ...

# %%
x_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 394       12.100         17.72           78.07      446.2          0.10290
# 527       12.340         12.27           78.94      468.5          0.09003
# 217       10.200         17.48           65.05      321.2          0.08054
# 505        9.676         13.14           64.12      272.5          0.12550
# 533       20.470         20.67          134.70     1299.0          0.09156
# 215       13.860         16.93           90.96      578.9          0.10260
# 341        9.606         16.84           61.64      280.5          0.08481
# 508       16.300         15.70          104.70      819.8          0.09427
# 374       13.690         16.07           87.84      579.1          0.08302
# 363       16.500         18.29          106.60      838.1          0.09686
# 303       10.490         18.61           66.86      334.3          0.10680
# ...

# %%
y_test
# Out:
# 394       Benign
# 527       Benign
# 217       Benign
# 505       Benign
# 533    Malignant
# 215    Malignant
# 341       Benign
# 508       Benign
# 374       Benign
# 363       Benign
# 303       Benign
# 185       Benign
# 44     Malignant
# 413       Benign
# 319       Benign
# 317    Malignant
# 397       Benign
# 199    Malignant
# 6      Malignant
# 33     Malignant
# 248       Benign
# 174       Benign
# 242       Benign
# 16     Malignant
# 126    Malignant
# 318       Benign
# 387       Benign
# 49        Benign
# 367       Benign
# 281       Benign
#          ...
# 337    Malignant
# 207    Malignant
# 278       Benign
# 343    Malignant
# 545       Benign
# 127    Malignant
# 301       Benign
# 393    Malignant
# 342       Benign
# 241       Benign
# 335    Malignant
# 373    Malignant
# 236    Malignant
# 76        Benign
# 368    Malignant
# 355       Benign
# 556       Benign
# 219    Malignant
# 121    Malignant
# 500       Benign
# 41     Malignant
# ...

# %%
clf=neighbors.KNeighborsClassifier()
clf.fit(x_train,y_train)
#clf is a classifier ,KNeighbors method under this we have fit method
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
#generating predictions using knn class
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array(['Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
# ...

# %%
#confusion matix is table to describe performance of classification model
#true positivemodel is more ,model is more accurate
from sklearn.metrics import confusion_matrix
clf_cm_test=confusion_matrix(y_test,y_pred)
clf_cm_test
# Out:
# array([[65,  2],
#        [ 6, 41]], dtype=int64)

# %%
# k value in knn is by default is sqroot(train)
#calculate acuuracy
accuracy=clf.score(x_test,y_test)

# %%
accuracy
# Out:
# 0.92982456140350878

# %%
from sklearn.svm import SVC
sc=SVC(kernel='rbf')
sc_classifier=sc.fit(x_train,y_train)

# %%
sc_classifier
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc_y_test=sc_classifier.predict(x_test)
print(svc_y_test)
# Out:
# ['Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
# ...

# %%
svc_y_train=sc_classifier.predict(x_train)
print(svc_y_train)
# Out:
# ['Benign' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant' 'Benign'
#  'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign' 'Benign' 'Benign'
#  'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign'
#  'Malignant' 'Malignant' 'Malignant' 'Malignant' 'Benign' 'Benign'
#  'Malignant' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Benign' 'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Malignant' 'Benign'
#  'Malignant' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Malignant'
#  'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Benign' 'Malignant' 'Benign'
#  'Benign' 'Benign' 'Benign' 'Malignant' 'Benign' 'Benign' 'Malignant'
# ...

# %%
#confusion matix is table to describe performance of classification model
#true positivemodel is more ,model is more accurate
from sklearn.metrics import confusion_matrix
clf_svc_test=confusion_matrix(y_test,svc_y_test)
clf_svc_test
# Out:
# array([[67,  0],
#        [47,  0]], dtype=int64)

# %%
#confusion matix is table to describe performance of classification model
#true positivemodel is more ,model is more accurate
from sklearn.metrics import confusion_matrix
clf_svc_train=confusion_matrix(y_train,svc_y_train)
clf_svc_train
# Out:
# array([[290,   0],
#        [  0, 165]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
svc_acc_test=accuracy_score(y_test,svc_y_test)
svc_acc_test
# Out:
# 0.58771929824561409

# %%
example_measures=np.array([15.44,12.54,150.9,998,0.2345,0.3452,0.2891,0.1234,0.3421,0.06879,2.076,0.8079,7.274,168.7,0.009786,0.03804,0.04372,0.02785,0.02002,0.007621,28.75,16.44,192.7,2025,0.1723,0.7752,0.7121,0.3421,0.4802,0.1278])
example_measures=example_measures.reshape(1,-1)

# %%
example_measures
# Out:
# array([[  1.54400000e+01,   1.25400000e+01,   1.50900000e+02,
#           9.98000000e+02,   2.34500000e-01,   3.45200000e-01,
#           2.89100000e-01,   1.23400000e-01,   3.42100000e-01,
#           6.87900000e-02,   2.07600000e+00,   8.07900000e-01,
#           7.27400000e+00,   1.68700000e+02,   9.78600000e-03,
#           3.80400000e-02,   4.37200000e-02,   2.78500000e-02,
#           2.00200000e-02,   7.62100000e-03,   2.87500000e+01,
#           1.64400000e+01,   1.92700000e+02,   2.02500000e+03,
#           1.72300000e-01,   7.75200000e-01,   7.12100000e-01,
#           3.42100000e-01,   4.80200000e-01,   1.27800000e-01]])

# %%
prediction=clf.predict(example_measures)
print(prediction)
# Out:
# ['Malignant']

# %%
from sklearn.metrics import accuracy_score
svc_acc_train=accuracy_score(y_train,svc_y_train)
svc_acc_train
# Out:
# 1.0

# %%
from sklearn.linear_model.logistic import LogisticRegression

# %%
cls=LogisticRegression(random_state=0)

# %%
lr_cls=cls.fit(x_train,y_train)

# %%
lr_cls
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=0, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr_y_test=lr_cls.predict(x_test)
lr_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
# ...

# %%
from sklearn.metrics import confusion_matrix
lr_cm_test=confusion_matrix(y_test,lr_y_test)
lr_cm_test
# Out:
# array([[66,  1],
#        [ 4, 43]], dtype=int64)

# %% [raw]
# from sklearn.metrics import accuracy_score
# lr_accu_test=accuracy_score(y_test,lr_y_test)

# %%
from sklearn.metrics import accuracy_score
lr_accu_test=accuracy_score(y_test,lr_y_test)

# %%
lr_accu_test
# Out:
# 0.95614035087719296

# %%
lr_y_train=cls.predict(x_train)

# %%
lr_accu_train=accuracy_score(y_train,lr_y_train)

# %%
lr_accu_train
# Out:
# 0.9538461538461539

# %%
y_test.shape,lr_y_test.shape
# Out:
# ((114,), (114,))

# %%
from sklearn.metrics import precision_score,classification_report
lr_precision_test=classification_report(y_test,lr_y_test)
print(lr_precision_test)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       0.94      0.99      0.96        67
#   Malignant       0.98      0.91      0.95        47
#
# avg / total       0.96      0.96      0.96       114

# %%
from sklearn.metrics import precision_score,classification_report
sv_precision_test=classification_report(y_test,svc_y_test)
print(sv_precision_test)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       0.59      1.00      0.74        67
#   Malignant       0.00      0.00      0.00        47
#
# avg / total       0.35      0.59      0.44       114
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn.metrics import precision_score,classification_report
sv_precision_train=classification_report(y_train,svc_y_train)
print(sv_precision_train)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       1.00      1.00      1.00       290
#   Malignant       1.00      1.00      1.00       165
#
# avg / total       1.00      1.00      1.00       455

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_clf=DecisionTreeClassifier()

# %%
dtc_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_clf
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
dtc_y_train=dtc_clf.predict(x_train)
dtc_y_train
# Out:
# array(['Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
# ...

# %%
dtc_y_test=dtc_clf.predict(x_test)
dtc_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
# ...

# %%
from sklearn.metrics import confusion_matrix
dtc_cm_test=confusion_matrix(y_test,dtc_y_test)
dtc_cm_test
# Out:
# array([[66,  1],
#        [ 8, 39]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
dtc_cm_train=confusion_matrix(y_train,dtc_y_train)
dtc_cm_train
# Out:
# array([[290,   0],
#        [  0, 165]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
dtc_accu_test=accuracy_score(y_test,dtc_y_test)

# %%
dtc_accu_test
# Out:
# 0.92105263157894735

# %%
dtc_accu_train=accuracy_score(y_train,dtc_y_train)
dtc_accu_train
# Out:
# 1.0

# %%
from sklearn.metrics import precision_score,classification_report
dtc_precision_train=classification_report(y_train,dtc_y_train)
print(dtc_precision_train)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       1.00      1.00      1.00       290
#   Malignant       1.00      1.00      1.00       165
#
# avg / total       1.00      1.00      1.00       455

# %%
from sklearn.metrics import precision_score,classification_report
dtc_precision_test=classification_report(y_test,dtc_y_test)
print(dtc_precision_test)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       0.89      0.99      0.94        67
#   Malignant       0.97      0.83      0.90        47
#
# avg / total       0.93      0.92      0.92       114

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rmf=RandomForestClassifier(max_depth=3,random_state=0)

# %%
rf_classi=rmf.fit(x_train,y_train)

# %%
rf_classi
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=3, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
rf_y_test=rf_classi.predict(x_test)

# %%
rf_y_test
# Out:
# array(['Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Malignant', 'Malignant', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
# ...

# %%
rf_y_train=rf_classi.predict(x_train)

# %%
rf_y_train
# Out:
# array(['Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Malignant', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Malignant', 'Benign', 'Benign', 'Benign', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Malignant', 'Malignant',
#        'Malignant', 'Benign', 'Benign', 'Malignant', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant',
#        'Benign', 'Benign', 'Benign', 'Benign', 'Malignant', 'Benign',
#        'Benign', 'Benign', 'Malignant', 'Benign', 'Malignant', 'Benign',
#        'Malignant', 'Benign', 'Benign', 'Benign', 'Benign', 'Malignant',
# ...

# %%
from sklearn.metrics import confusion_matrix
rf_cm_test=confusion_matrix(y_test,rf_y_test)
rf_cm_test
# Out:
# array([[67,  0],
#        [ 6, 41]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
rf_cm_train=confusion_matrix(y_train,rf_y_train)
rf_cm_train
# Out:
# array([[289,   1],
#        [  9, 156]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
rf_accu_test=accuracy_score(y_test,rf_y_test)

# %%
rf_accu_test
# Out:
# 0.94736842105263153

# %%
from sklearn.metrics import accuracy_score
rf_accu_train=accuracy_score(y_train,rf_y_train)

# %%
rf_accu_train
# Out:
# 0.97802197802197799

# %%
from sklearn.metrics import precision_score,classification_report
rf_precision_test=classification_report(y_test,rf_y_test)
print(rf_precision_test)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       0.92      1.00      0.96        67
#   Malignant       1.00      0.87      0.93        47
#
# avg / total       0.95      0.95      0.95       114

# %%
from sklearn.metrics import precision_score,classification_report
dtc_precision_train=classification_report(y_train,dtc_y_train)
print(dtc_precision_train)
# Out:
#              precision    recall  f1-score   support
#
#      Benign       1.00      1.00      1.00       290
#   Malignant       1.00      1.00      1.00       165
#
# avg / total       1.00      1.00      1.00       455

# %%
from sklearn import model_selection
from sklearn.ensemble import AdaBoostClassifier
seed=7
num_trees=30
kfold=model_selection.KFold(n_splits=10,random_state=seed)
model=AdaBoostClassifier(n_estimators=num_trees,random_state=seed)
results=model_selection.cross_val_score(model,x_train,y_train,cv=kfold)

# %%
results
# Out:
# array([ 0.95652174,  0.97826087,  1.        ,  0.93478261,  0.97826087,
#         0.91111111,  0.93333333,  1.        ,  0.95555556,  0.95555556])

# %%
kfold
# Out:
# KFold(n_splits=10, random_state=7, shuffle=False)

# %%
model
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=30, random_state=7)
