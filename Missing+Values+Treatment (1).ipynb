# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents'

# %%
os.chdir("C:/Users/dell/Documents")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv('bikebuyer1.csv')

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
#Examine Yearly Income
data1['Yearly Income'].min()
# Out:
# 0

# %%
data1['Yearly Income'].max()
# Out:
# 170000

# %%
data1['Yearly Income'].mean()
# Out:
# 57020.151493497215

# %%
data1['Yearly Income'].median()
# Out:
# 60000.0

# %%
np.std(data1['Yearly Income'])
# Out:
# 32078.15719490367

# %%
np.var(data1['Yearly Income'])
# Out:
# 1029008169.0209501

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data1.boxplot(column='Yearly Income')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   app.launch_new_instance()
# {'boxes': [<matplotlib.lines.Line2D at 0x93bd898>],
#  'caps': [<matplotlib.lines.Line2D at 0x93cbc88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x93dbb00>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x93d7c18>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x93bdb38>,
#   <matplotlib.lines.Line2D at 0x93cbb00>]}

# %%
#Examine Gender
data1['Gender'].count()
# Out:
# 6968

# %%
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
#Get a count of missing values in the dataset,columns are refered as axis
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender              29
# Yearly Income        2
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
#Examine Marital Status
data1['Marital Status'].value_counts()
# Out:
# Married    4149
# Single     2848
# Name: Marital Status, dtype: int64

# %%
data1 ['Marital Status'].fillna('Married', inplace=True)
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male        30000.0       0.0
# 1     13555.0        Married  Female        40000.0       0.0
# 2         NaN        Married    Male       160000.0       5.0
# 3         2.0         Single    Male       160000.0       0.0
# 4     25410.0        Married  Female        70000.0       2.0
# 5         4.0        Married     NaN       120000.0       2.0
# 6     15756.0         Single  Female        70000.0       0.0
# 7     11085.0         Single  Female        60000.0       0.0
# 8     17974.0        Married  Female            NaN       NaN
# 9     21008.0         Single  Female        20000.0       1.0
# 10    28985.0         Single    Male        50000.0       0.0
# 11    11087.0        Married  Female        70000.0       2.0
# 12    20434.0         Single     NaN        60000.0       0.0
# 13    14902.0        Married  Female        40000.0       0.0
# ...

# %%
# After imputation Get a count of missing values in the dataset
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender              29
# Yearly Income        2
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
data1['Yearly Income']=data1['Yearly Income'].replace(0,np.NaN)

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male        30000.0       0.0
# 1     13555.0        Married  Female        40000.0       0.0
# 2         NaN        Married    Male       160000.0       5.0
# 3         2.0         Single    Male       160000.0       0.0
# 4     25410.0            NaN  Female        70000.0       2.0
# 5         4.0        Married     NaN       120000.0       2.0
# 6     15756.0         Single  Female        70000.0       0.0
# 7     11085.0         Single  Female        60000.0       0.0
# 8     17974.0            NaN  Female            NaN       NaN
# 9     21008.0         Single  Female        20000.0       1.0
# 10    28985.0         Single    Male        50000.0       0.0
# 11    11087.0        Married  Female        70000.0       2.0
# 12    20434.0         Single     NaN        60000.0       0.0
# 13    14902.0            NaN  Female        40000.0       0.0
# ...

# %%
data1['Gender'].value_counts()
# Out:
# Male      3527
# Female    3441
# Name: Gender, dtype: int64

# %%
data1['Gender'].fillna('Male',inplace=True)

# %%
data1
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male        30000.0       0.0
# 1     13555.0        Married  Female        40000.0       0.0
# 2         NaN        Married    Male       160000.0       5.0
# 3         2.0         Single    Male       160000.0       0.0
# 4     25410.0        Married  Female        70000.0       2.0
# 5         4.0        Married    Male       120000.0       2.0
# 6     15756.0         Single  Female        70000.0       0.0
# 7     11085.0         Single  Female        60000.0       0.0
# 8     17974.0        Married  Female            NaN       NaN
# 9     21008.0         Single  Female        20000.0       1.0
# 10    28985.0         Single    Male        50000.0       0.0
# 11    11087.0        Married  Female        70000.0       2.0
# 12    20434.0         Single    Male        60000.0       0.0
# 13    14902.0        Married  Female        40000.0       0.0
# ...

# %%
# After imputation Get a count of missing values in the dataset
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status       0
# Gender               0
# Yearly Income        2
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data1.fillna(data1.mean(),inplace=True)
# Out:
#                 ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.000000         Single    Male    30000.00000  0.000000
# 1     13555.000000        Married  Female    40000.00000  0.000000
# 2     17744.435249        Married    Male   160000.00000  5.000000
# 3         2.000000         Single    Male   160000.00000  0.000000
# 4     25410.000000        Married  Female    70000.00000  2.000000
# 5         4.000000        Married    Male   120000.00000  2.000000
# 6     15756.000000         Single  Female    70000.00000  0.000000
# 7     11085.000000         Single  Female    60000.00000  0.000000
# 8     17974.000000        Married  Female    57036.45461  1.111621
# 9     21008.000000         Single  Female    20000.00000  1.000000
# 10    28985.000000         Single    Male    50000.00000  0.000000
# 11    11087.000000        Married  Female    70000.00000  2.000000
# 12    20434.000000         Single    Male    60000.00000  0.000000
# ...

# %%
# After imputation Get a count of missing values in the dataset
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data1
# Out:
#                 ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.000000         Single    Male    30000.00000  0.000000
# 1     13555.000000        Married  Female    40000.00000  0.000000
# 2     17744.435249        Married    Male   160000.00000  5.000000
# 3         2.000000         Single    Male   160000.00000  0.000000
# 4     25410.000000        Married  Female    70000.00000  2.000000
# 5         4.000000        Married    Male   120000.00000  2.000000
# 6     15756.000000         Single  Female    70000.00000  0.000000
# 7     11085.000000         Single  Female    60000.00000  0.000000
# 8     17974.000000        Married  Female    57036.45461  1.111621
# 9     21008.000000         Single  Female    20000.00000  1.000000
# 10    28985.000000         Single    Male    50000.00000  0.000000
# 11    11087.000000        Married  Female    70000.00000  2.000000
# 12    20434.000000         Single    Male    60000.00000  0.000000
# ...

# %%
# After imputation Get a count of missing values in the dataset
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                  0
# Marital Status      0
# Gender              0
# Yearly Income       0
# Children            0
# Education           0
# Occupation          0
# Home Owner          0
# Cars                0
# Commute Distance    0
# Region              0
# Age                 0
# Bike Buyer          0
# dtype: int64

# %%
data2=pd.read_csv('bikebuyer1.csv')

# %%
data2
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male          30000       0.0
# 1     13555.0        Married  Female          40000       0.0
# 2         NaN        Married    Male         160000       5.0
# 3         2.0         Single    Male         160000       0.0
# 4     25410.0            NaN  Female          70000       2.0
# 5         4.0        Married     NaN         120000       2.0
# 6     15756.0         Single  Female          70000       0.0
# 7     11085.0         Single  Female          60000       0.0
# 8     17974.0            NaN  Female              0       NaN
# 9     21008.0         Single  Female          20000       1.0
# 10    28985.0         Single    Male          50000       0.0
# 11    11087.0        Married  Female          70000       2.0
# 12    20434.0         Single     NaN          60000       0.0
# 13    14902.0            NaN  Female          40000       0.0
# ...

# %%
# After imputation Get a count of missing values in the dataset
data2.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status      16
# Gender              29
# Yearly Income        0
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
data2['Yearly Income']=data2['Yearly Income'].replace(0,np.NaN)

# %%
data2
# Out:
#            ID Marital Status  Gender  Yearly Income  Children  \
# 0     22711.0         Single    Male        30000.0       0.0
# 1     13555.0        Married  Female        40000.0       0.0
# 2         NaN        Married    Male       160000.0       5.0
# 3         2.0         Single    Male       160000.0       0.0
# 4     25410.0            NaN  Female        70000.0       2.0
# 5         4.0        Married     NaN       120000.0       2.0
# 6     15756.0         Single  Female        70000.0       0.0
# 7     11085.0         Single  Female        60000.0       0.0
# 8     17974.0            NaN  Female            NaN       NaN
# 9     21008.0         Single  Female        20000.0       1.0
# 10    28985.0         Single    Male        50000.0       0.0
# 11    11087.0        Married  Female        70000.0       2.0
# 12    20434.0         Single     NaN        60000.0       0.0
# 13    14902.0            NaN  Female        40000.0       0.0
# ...

# %%
# After imputation Get a count of missing values in the dataset
data2.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# ID                   1
# Marital Status      16
# Gender              29
# Yearly Income        2
# Children            18
# Education            0
# Occupation           0
# Home Owner           0
# Cars                 0
# Commute Distance    29
# Region               0
# Age                  0
# Bike Buyer           0
# dtype: int64

# %%
# use Sci-kit learn Imputer()
from sklearn.preprocessing import Imputer
import numpy as np
values=data2[['Yearly Income','Commute Distance','Children']]
imputer=Imputer()
transformed_values=imputer.fit_transform(values)
#Count the number of NaN values in each column
print(np.isnan(transformed_values).sum())
# Out:
# 0
