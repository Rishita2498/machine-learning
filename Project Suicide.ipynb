# %%
import os
import pandas as pd
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents'

# %%
os.chdir('E:\machine learning')

# %%
data=pd.read_csv('Suicide Statistics in Indian States.csv')

# %%
data
# Out:
#     Sl. No. Category              State/UT/City  Males Involved  \
# 0         1    State             Andhra Pradesh            4275
# 1         2    State                      Assam            1557
# 2         3    State                      Bihar            5422
# 3         4    State                    Gujarat            4276
# 4         5    State                    Haryana             788
# 5         6    State          Jammu and Kashmir             344
# 6         7    State                     Kerala            2428
# 7         8    State             Madhya Pradesh            9150
# 8         9    State                Maharashtra           12687
# 9        10    State                     Mysore            5242
# 10       11    State                   Nagaland              10
# 11       12    State                     Orissa            3805
# 12       13    State                     Punjab            1160
# 13       14    State                  Rajasthan            1556
# ...
