# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
os.chdir('C:/Users/dell/Desktop/datas')

# %%
data=pd.read_csv('Haliotidae.csv')

# %%
data
# Out:
#     length  diameter  height  Whole Weight  Shucked Weight  Viscera Weight  \
# 0    0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1    0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2    0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3    0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4    0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5    0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6    0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7    0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8    0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9    0.550     0.440   0.150        0.8945          0.3145          0.1510
# 10   0.525     0.380   0.140        0.6065          0.1940          0.1475
# ...

# %%
x = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
x
# Out:
# array([[ 0.455 ,  0.365 ,  0.095 ,  0.514 ,  0.2245,  0.101 ,  0.15  ],
#        [ 0.35  ,  0.265 ,  0.09  ,  0.2255,  0.0995,  0.0485,  0.07  ],
#        [ 0.53  ,  0.42  ,  0.135 ,  0.677 ,  0.2565,  0.1415,  0.21  ],
#        [ 0.44  ,  0.365 ,  0.125 ,  0.516 ,  0.2155,  0.114 ,  0.155 ],
#        [ 0.33  ,  0.255 ,  0.08  ,  0.205 ,  0.0895,  0.0395,  0.055 ],
#        [ 0.425 ,  0.3   ,  0.095 ,  0.3515,  0.141 ,  0.0775,  0.12  ],
#        [ 0.53  ,  0.415 ,  0.15  ,  0.7775,  0.237 ,  0.1415,  0.33  ],
#        [ 0.545 ,  0.425 ,  0.125 ,  0.768 ,  0.294 ,  0.1495,  0.26  ],
#        [ 0.475 ,  0.37  ,  0.125 ,  0.5095,  0.2165,  0.1125,  0.165 ],
#        [ 0.55  ,  0.44  ,  0.15  ,  0.8945,  0.3145,  0.151 ,  0.32  ],
#        [ 0.525 ,  0.38  ,  0.14  ,  0.6065,  0.194 ,  0.1475,  0.21  ],
#        [ 0.43  ,  0.35  ,  0.11  ,  0.406 ,  0.1675,  0.081 ,  0.135 ],
#        [ 0.49  ,  0.38  ,  0.135 ,  0.5415,  0.2175,  0.095 ,  0.19  ],
# ...

# %%
y
# Out:
# array([15,  7,  9, 10,  7,  8, 20, 16,  9, 19, 14, 10, 11, 10, 10, 12,  7,
#        10,  7,  9, 11, 10, 12,  9, 10, 11, 11, 12, 15, 11, 10, 15, 18, 19,
#        13,  8, 16,  8, 11,  9,  9, 14,  5,  5,  4,  7,  9,  7,  6,  9,  8,
#         7, 10, 10,  7,  8,  8,  8,  4,  7,  7,  9, 10,  7,  8,  8, 12, 13,
#        10,  6, 13,  8, 20, 11, 13, 15,  9, 10, 11, 14,  9, 12, 16, 21, 14,
#        12, 13, 10,  9, 12, 15, 12, 13, 10, 15, 14,  9,  8,  7], dtype=int64)

# %%
#y=y.reshape([-1,1])#convert to column matrix
#y.shape

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x_train
# Out:
# array([[ 0.205 ,  0.15  ,  0.055 ,  0.042 ,  0.0255,  0.015 ,  0.012 ],
#        [ 0.53  ,  0.41  ,  0.13  ,  0.6965,  0.302 ,  0.1935,  0.2   ],
#        [ 0.44  ,  0.365 ,  0.125 ,  0.516 ,  0.2155,  0.114 ,  0.155 ],
#        [ 0.4   ,  0.32  ,  0.11  ,  0.353 ,  0.1405,  0.0985,  0.1   ],
#        [ 0.39  ,  0.295 ,  0.095 ,  0.203 ,  0.0875,  0.045 ,  0.075 ],
#        [ 0.325 ,  0.245 ,  0.07  ,  0.161 ,  0.0755,  0.0255,  0.045 ],
#        [ 0.53  ,  0.415 ,  0.15  ,  0.7775,  0.237 ,  0.1415,  0.33  ],
#        [ 0.47  ,  0.37  ,  0.13  ,  0.5225,  0.201 ,  0.133 ,  0.165 ],
#        [ 0.52  ,  0.425 ,  0.165 ,  0.9885,  0.396 ,  0.225 ,  0.32  ],
#        [ 0.595 ,  0.475 ,  0.14  ,  0.944 ,  0.3625,  0.189 ,  0.315 ],
#        [ 0.45  ,  0.345 ,  0.105 ,  0.4115,  0.18  ,  0.1125,  0.135 ],
#        [ 0.575 ,  0.445 ,  0.14  ,  0.941 ,  0.3845,  0.252 ,  0.285 ],
#        [ 0.575 ,  0.45  ,  0.16  ,  0.9775,  0.3135,  0.231 ,  0.33  ],
# ...

# %%
x_test
# Out:
# array([[ 0.58  ,  0.45  ,  0.185 ,  0.9955,  0.3945,  0.272 ,  0.285 ],
#        [ 0.625 ,  0.465 ,  0.14  ,  1.195 ,  0.4825,  0.205 ,  0.4   ],
#        [ 0.53  ,  0.42  ,  0.135 ,  0.677 ,  0.2565,  0.1415,  0.21  ],
#        [ 0.5   ,  0.4   ,  0.14  ,  0.6615,  0.2565,  0.1755,  0.22  ],
#        [ 0.6   ,  0.475 ,  0.15  ,  1.0075,  0.4425,  0.221 ,  0.28  ],
#        [ 0.595 ,  0.465 ,  0.175 ,  1.115 ,  0.4015,  0.254 ,  0.39  ],
#        [ 0.355 ,  0.28  ,  0.085 ,  0.2905,  0.095 ,  0.0395,  0.115 ],
#        [ 0.57  ,  0.48  ,  0.175 ,  1.185 ,  0.474 ,  0.261 ,  0.38  ],
#        [ 0.405 ,  0.31  ,  0.1   ,  0.385 ,  0.173 ,  0.0915,  0.11  ],
#        [ 0.695 ,  0.56  ,  0.19  ,  1.494 ,  0.588 ,  0.3425,  0.485 ],
#        [ 0.47  ,  0.36  ,  0.12  ,  0.4775,  0.2105,  0.1055,  0.15  ],
#        [ 0.555 ,  0.44  ,  0.15  ,  0.755 ,  0.307 ,  0.1525,  0.26  ],
#        [ 0.555 ,  0.425 ,  0.14  ,  0.788 ,  0.282 ,  0.1595,  0.285 ],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)

# %%
x_test
# Out:
# array([[  8.26616306e-01,   7.38742740e-01,   1.67420338e+00,
#           7.72209299e-01,   8.52148546e-01,   1.37588299e+00,
#           4.81348430e-01],
#        [  1.25096590e+00,   9.09888419e-01,   3.66117003e-01,
#           1.27734158e+00,   1.46643066e+00,   6.08369825e-01,
#           1.33164018e+00],
#        [  3.55116753e-01,   3.96451383e-01,   2.20774072e-01,
#          -3.42299596e-02,  -1.11157494e-01,  -1.19049369e-01,
#          -7.31896699e-02],
#        [  7.22170203e-02,   1.68257144e-01,   3.66117003e-01,
#          -7.34758262e-02,  -1.11157494e-01,   2.70434924e-01,
#           7.48743426e-04],
#        [  1.01521613e+00,   1.02398554e+00,   6.56802865e-01,
#           8.02593196e-01,   1.18721152e+00,   7.91656551e-01,
#           4.44379223e-01],
#        [  9.68066173e-01,   9.09888419e-01,   1.38351752e+00,
#           1.07478227e+00,   9.01011896e-01,   1.16968542e+00,
#           1.25770177e+00],
# ...

# %%
#sc_y = StandardScaler()
#y_train = sc_y.fit_transform(y_train)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([ 12.44799652,  14.26016224,  10.31922217,  10.87169249,
#         11.98578738,  14.30416911,   7.71811714,  13.74808527,
#          8.20037973,  16.27543148,   9.52310092,  11.98849294,
#         12.11876942,  10.71846789,  11.33110041,  13.22222489,
#         12.17927332,  12.63402485,  14.65669067,   9.7945492 ])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
# length            99 non-null float64
# diameter          99 non-null float64
# height            99 non-null float64
# Whole Weight      99 non-null float64
# Shucked Weight    99 non-null float64
# Viscera Weight    99 non-null float64
# Shells Weight     99 non-null float64
# rings             99 non-null int64
# dtypes: float64(7), int64(1)
# memory usage: 6.3 KB

# %%
length=data['length']

# %%
length
# Out:
# 0     0.455
# 1     0.350
# 2     0.530
# 3     0.440
# 4     0.330
# 5     0.425
# 6     0.530
# 7     0.545
# 8     0.475
# 9     0.550
# 10    0.525
# 11    0.430
# 12    0.490
# 13    0.535
# 14    0.470
# 15    0.500
# 16    0.355
# 17    0.440
# 18    0.365
# 19    0.450
# 20    0.355
# 21    0.380
# 22    0.565
# 23    0.550
# 24    0.615
# 25    0.560
# 26    0.580
# 27    0.590
# 28    0.605
# 29    0.575
#       ...
# 69    0.310
# 70    0.555
# 71    0.400
# 72    0.595
# 73    0.570
# 74    0.605
# 75    0.600
# 76    0.595
# 77    0.600
# 78    0.555
# 79    0.615
# 80    0.575
# 81    0.620
# 82    0.520
# 83    0.595
# 84    0.580
# 85    0.570
# 86    0.625
# 87    0.560
# 88    0.460
# 89    0.575
# 90    0.565
# 91    0.555
# 92    0.595
# 93    0.625
# 94    0.695
# 95    0.665
# 96    0.535
# 97    0.470
# 98    0.470
# Name: length, dtype: float64

# %%
rings=data['rings']

# %%
rings
# Out:
# 0     15
# 1      7
# 2      9
# 3     10
# 4      7
# 5      8
# 6     20
# 7     16
# 8      9
# 9     19
# 10    14
# 11    10
# 12    11
# 13    10
# 14    10
# 15    12
# 16     7
# 17    10
# 18     7
# 19     9
# 20    11
# 21    10
# 22    12
# 23     9
# 24    10
# 25    11
# 26    11
# 27    12
# 28    15
# 29    11
#       ..
# 69     6
# 70    13
# 71     8
# 72    20
# 73    11
# 74    13
# 75    15
# 76     9
# 77    10
# 78    11
# 79    14
# 80     9
# 81    12
# 82    16
# 83    21
# 84    14
# 85    12
# 86    13
# 87    10
# 88     9
# 89    12
# 90    15
# 91    12
# 92    13
# 93    10
# 94    15
# 95    14
# 96     9
# 97     8
# 98     7
# Name: rings, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ax=plt.plot(length,rings,'o')
plt.ylabel("rings")
plt.xlabel("length")

# %%
height=data['height']

# %%
height
# Out:
# 0     0.095
# 1     0.090
# 2     0.135
# 3     0.125
# 4     0.080
# 5     0.095
# 6     0.150
# 7     0.125
# 8     0.125
# 9     0.150
# 10    0.140
# 11    0.110
# 12    0.135
# 13    0.145
# 14    0.100
# 15    0.130
# 16    0.085
# 17    0.100
# 18    0.080
# 19    0.100
# 20    0.095
# 21    0.100
# 22    0.155
# 23    0.135
# 24    0.165
# 25    0.140
# 26    0.185
# 27    0.140
# 28    0.180
# 29    0.140
#       ...
# 69    0.070
# 70    0.130
# 71    0.110
# 72    0.170
# 73    0.175
# 74    0.195
# 75    0.150
# 76    0.140
# 77    0.150
# 78    0.140
# 79    0.170
# 80    0.140
# 81    0.175
# 82    0.165
# 83    0.160
# 84    0.140
# 85    0.180
# 86    0.140
# 87    0.160
# 88    0.130
# 89    0.160
# 90    0.135
# 91    0.150
# 92    0.175
# 93    0.165
# 94    0.190
# 95    0.195
# 96    0.150
# 97    0.130
# 98    0.130
# Name: height, dtype: float64

# %%
ax=plt.plot(height,rings,'o')
plt.ylabel("rings")
plt.xlabel("height")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
# length            99 non-null float64
# diameter          99 non-null float64
# height            99 non-null float64
# Whole Weight      99 non-null float64
# Shucked Weight    99 non-null float64
# Viscera Weight    99 non-null float64
# Shells Weight     99 non-null float64
# rings             99 non-null int64
# dtypes: float64(7), int64(1)
# memory usage: 6.3 KB

# %%
diameter=data['diameter']

# %%
ax=plt.plot(diameter,rings,'o')
plt.ylabel("rings")
plt.xlabel("diameter")

# %%
WholeWeight=data['Whole Weight']

# %%
ax=plt.plot(WholeWeight,rings,'o')
plt.ylabel("rings")
plt.xlabel("Whole Weight")

# %%
ShuckedWeight=data['Shucked Weight']

# %%
ax=plt.plot(ShuckedWeight,rings,'o')
plt.ylabel("rings")
plt.xlabel("Shucked Weight")

# %%
o=data['rings']
o=o.reshape(1,-1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
# length            99 non-null float64
# diameter          99 non-null float64
# height            99 non-null float64
# Whole Weight      99 non-null float64
# Shucked Weight    99 non-null float64
# Viscera Weight    99 non-null float64
# Shells Weight     99 non-null float64
# rings             99 non-null int64
# dtypes: float64(7), int64(1)
# memory usage: 6.3 KB

# %%
from sklearn import linear_model
c=data['Whole Weight']
d=data['Shucked Weight']
c=c.reshape(1,-1)
d=d.reshape(1,-1)

# %%
a=data['length']
b=data['diameter']
e=data['Viscera Weight']
f=data['Shells Weight']
a=a.reshape(1,-1)
b=b.reshape(1,-1)
e=e.reshape(1,-1)
f=f.reshape(1,-1)

# %%
lm=linear_model.LinearRegression()
model_multiple=lm.fit(o,a+b+c+d+e+f)

# %%
model_multiple
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
predictions=lm.predict(a)
print(predictions)
# Out:
# [[ 1.8095  1.0585  2.235   1.8055  0.974   1.415   2.431   2.4415  1.8485
#    2.67    2.063   1.5695  1.914   2.273   1.7335  2.1955  1.175   1.636
#    1.1555  1.5115  1.113   1.0945  2.856   2.4565  3.3755  2.799   2.977
#    2.836   2.9245  2.6835  3.013   4.225   3.787   4.6905  4.499   1.7755
#    3.41    1.826   2.7475  1.2825  1.6025  2.6545  0.56    0.4495  0.447
#    1.0955  2.0795  1.733   0.877   2.5985  2.0645  1.3165  1.902   1.7735
#    1.4745  2.2135  1.66    2.011   0.602   2.039   1.634   2.175   2.332
#    1.479   2.0505  1.7805  2.7875  3.5     1.8945  0.8445  2.4535  1.412
#    3.447   3.35    3.2385  3.026   2.8805  2.854   2.4945  3.2425  2.8825
#    4.1225  2.8745  3.6095  2.999   3.3315  3.3725  2.6625  1.8315  2.877
#    2.565   2.4695  3.2205  3.597   4.1645  4.2495  2.3525  1.859   1.8615]]

# %%
predictions=lm.predict(b)
print(predictions)
# Out:
# [[ 1.8095  1.0585  2.235   1.8055  0.974   1.415   2.431   2.4415  1.8485
#    2.67    2.063   1.5695  1.914   2.273   1.7335  2.1955  1.175   1.636
#    1.1555  1.5115  1.113   1.0945  2.856   2.4565  3.3755  2.799   2.977
#    2.836   2.9245  2.6835  3.013   4.225   3.787   4.6905  4.499   1.7755
#    3.41    1.826   2.7475  1.2825  1.6025  2.6545  0.56    0.4495  0.447
#    1.0955  2.0795  1.733   0.877   2.5985  2.0645  1.3165  1.902   1.7735
#    1.4745  2.2135  1.66    2.011   0.602   2.039   1.634   2.175   2.332
#    1.479   2.0505  1.7805  2.7875  3.5     1.8945  0.8445  2.4535  1.412
#    3.447   3.35    3.2385  3.026   2.8805  2.854   2.4945  3.2425  2.8825
#    4.1225  2.8745  3.6095  2.999   3.3315  3.3725  2.6625  1.8315  2.877
#    2.565   2.4695  3.2205  3.597   4.1645  4.2495  2.3525  1.859   1.8615]]

# %%
predictions=lm.predict(c)
print(predictions)
# Out:
# [[ 1.8095  1.0585  2.235   1.8055  0.974   1.415   2.431   2.4415  1.8485
#    2.67    2.063   1.5695  1.914   2.273   1.7335  2.1955  1.175   1.636
#    1.1555  1.5115  1.113   1.0945  2.856   2.4565  3.3755  2.799   2.977
#    2.836   2.9245  2.6835  3.013   4.225   3.787   4.6905  4.499   1.7755
#    3.41    1.826   2.7475  1.2825  1.6025  2.6545  0.56    0.4495  0.447
#    1.0955  2.0795  1.733   0.877   2.5985  2.0645  1.3165  1.902   1.7735
#    1.4745  2.2135  1.66    2.011   0.602   2.039   1.634   2.175   2.332
#    1.479   2.0505  1.7805  2.7875  3.5     1.8945  0.8445  2.4535  1.412
#    3.447   3.35    3.2385  3.026   2.8805  2.854   2.4945  3.2425  2.8825
#    4.1225  2.8745  3.6095  2.999   3.3315  3.3725  2.6625  1.8315  2.877
#    2.565   2.4695  3.2205  3.597   4.1645  4.2495  2.3525  1.859   1.8615]]

# %%
predictions=lm.predict(d)
print(predictions)
# Out:
# [[ 1.8095  1.0585  2.235   1.8055  0.974   1.415   2.431   2.4415  1.8485
#    2.67    2.063   1.5695  1.914   2.273   1.7335  2.1955  1.175   1.636
#    1.1555  1.5115  1.113   1.0945  2.856   2.4565  3.3755  2.799   2.977
#    2.836   2.9245  2.6835  3.013   4.225   3.787   4.6905  4.499   1.7755
#    3.41    1.826   2.7475  1.2825  1.6025  2.6545  0.56    0.4495  0.447
#    1.0955  2.0795  1.733   0.877   2.5985  2.0645  1.3165  1.902   1.7735
#    1.4745  2.2135  1.66    2.011   0.602   2.039   1.634   2.175   2.332
#    1.479   2.0505  1.7805  2.7875  3.5     1.8945  0.8445  2.4535  1.412
#    3.447   3.35    3.2385  3.026   2.8805  2.854   2.4945  3.2425  2.8825
#    4.1225  2.8745  3.6095  2.999   3.3315  3.3725  2.6625  1.8315  2.877
#    2.565   2.4695  3.2205  3.597   4.1645  4.2495  2.3525  1.859   1.8615]]

# %%
y=a+b+c+d+e+f
y
# Out:
# array([[ 1.8095,  1.0585,  2.235 ,  1.8055,  0.974 ,  1.415 ,  2.431 ,
#          2.4415,  1.8485,  2.67  ,  2.063 ,  1.5695,  1.914 ,  2.273 ,
#          1.7335,  2.1955,  1.175 ,  1.636 ,  1.1555,  1.5115,  1.113 ,
#          1.0945,  2.856 ,  2.4565,  3.3755,  2.799 ,  2.977 ,  2.836 ,
#          2.9245,  2.6835,  3.013 ,  4.225 ,  3.787 ,  4.6905,  4.499 ,
#          1.7755,  3.41  ,  1.826 ,  2.7475,  1.2825,  1.6025,  2.6545,
#          0.56  ,  0.4495,  0.447 ,  1.0955,  2.0795,  1.733 ,  0.877 ,
#          2.5985,  2.0645,  1.3165,  1.902 ,  1.7735,  1.4745,  2.2135,
#          1.66  ,  2.011 ,  0.602 ,  2.039 ,  1.634 ,  2.175 ,  2.332 ,
#          1.479 ,  2.0505,  1.7805,  2.7875,  3.5   ,  1.8945,  0.8445,
#          2.4535,  1.412 ,  3.447 ,  3.35  ,  3.2385,  3.026 ,  2.8805,
#          2.854 ,  2.4945,  3.2425,  2.8825,  4.1225,  2.8745,  3.6095,
#          2.999 ,  3.3315,  3.3725,  2.6625,  1.8315,  2.877 ,  2.565 ,
# ...

# %%
import seaborn as sns
ax=plt.plot(y,o,'o')
plt.ylabel("rings")
plt.xlabel("factors")
plt.show()
